# %%
import pandas as pd

# %%
data = pd.read_parquet("students.parquet")

# %%
data.sample(10)
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 94           95   23    Male       Graduate      Bosnia
# 199         200   22    Male       Graduate    Pakistan
# 166         167   20  Female  Undergraduate  Bangladesh
# 279         280   22    Male       Graduate     Germany
# 378         379   20  Female  Undergraduate      France
# 393         394   21    Male       Graduate       India
# 236         237   19  Female  Undergraduate         USA
# 551         552   22    Male       Graduate       China
# 173         174   21    Male       Graduate       India
# 536         537   19  Female  Undergraduate         UAE
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 94                     2.4           LinkedIn                           No
# 199                    4.1          Instagram                          Yes
# 166                    4.9          Instagram                          Yes
# ...
